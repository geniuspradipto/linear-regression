# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9d97d769-665d-4d8d-b559-73d23494efd6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d97d769-665d-4d8d-b559-73d23494efd6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('headbrain.csv')
df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
X = df['Head Size(cm^3)'].values
y = df['Brain Weight(grams)'].values

plt.scatter(X, y, color = 'red')
plt.xlabel('Head Size(cm^3) -->')
plt.ylabel('Brain Weight(grams) -->')

plt.title('Linear Regression')

plt.show()

# %%
df.describe()
# Out:
#            Gender   Age Range  Head Size(cm^3)  Brain Weight(grams)
# count  237.000000  237.000000       237.000000           237.000000
# mean     1.434599    1.535865      3633.991561          1282.873418
# std      0.496753    0.499768       365.261422           120.340446
# min      1.000000    1.000000      2720.000000           955.000000
# 25%      1.000000    1.000000      3389.000000          1207.000000
# 50%      1.000000    2.000000      3614.000000          1280.000000
# 75%      2.000000    2.000000      3876.000000          1350.000000
# max      2.000000    2.000000      4747.000000          1635.000000

# %%
# most imp step
from sklearn.linear_model import LinearRegression # import stmt
reg = LinearRegression() #obj creation # ML model creation

# reshape
n = len(X)
X = X.reshape((n,1))
# model train
reg.fit(X,y)
#predict
y_pred = reg.predict(X)

# %%
import numpy as np
arr = np.array([[10, 20, 30],[40,50,60]])
arr2 = arr.reshape(6,1)
print(arr2)
# Out:
# [[10]
#  [20]
#  [30]
#  [40]
#  [50]
#  [60]]

# %%
plt.scatter(y,X, color='red')
plt.plot(y_pred,X, color='black')
plt.show()

# %%
ip = float(input("Enter Head Size:  "))


res = reg.predict([[ip]])
print(res)
# Out:
# Enter Head Size:  3700
# [1300.26197716]

# %%
acc = reg.score(X,y)
print(acc*100)
# Out:
# 63.9311719957

# %%
# step 5 : import ml algo

from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error


# step 6: reshape(optional)

X = X.reshape((n,1)) #important : converts into column wise array


# step 7 : most important : model creation
reg = LinearRegression() # obj create
#fit the training data : model training
reg = reg.fit(X, Y)

# step 8: prediction
Y_pred = reg.predict(X)

r2_value = reg.score(X, Y)
print(r2_value)

from sklearn.metrics import mean_squared_error
acc = model.score(X,Y)
print(acc)
# Out:
# 0.639311719957
